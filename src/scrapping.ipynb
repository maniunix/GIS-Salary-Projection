# %% [markdown]
# ## Import Libraries

# %%
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium import webdriver
import time
import pandas as pd
from selenium.webdriver.common.by import By
from getDataframe import getDataframe

# %% [markdown]
# __Defined Class and Methods__

# %%
class scrapper:
    ##### Scrapper Accepts the #####
    ##### ** Keyword ** which will be JOB ROLE #####
    ##### ** location ** which will be location of interest i.e. India #####
    ##### ** Page ** Total number of Pages you would like to scrap #####

    def __init__(self, keyword, location, page):
        self.keyword = keyword
        self.location = location
        self.page = page

    def getJobDesc(self):
        path = "E:/Workspace/gis_salary_proj/chromedriver"
        options = webdriver.ChromeOptions()
        driver = webdriver.Chrome(executable_path=path, options=options)
        driver.set_window_size(1120, 1000)
        job_desc = []
        url = f"https://in.indeed.com/jobs?q={self.keyword}&l={self.location}&start={self.page}0&pp=gQAPAAABhjpfH0EAAAAB-HMzigAdAQA9j26Kn2PmZeS6I04EDTkITNq89HjrpZMf1aYAAA&vjk=f71c00e996a2405e"
        driver.get(url)
        driver.implicitly_wait(20)
        try:
            job_description = driver.find_element(
                By.ID, "mosaic-provider-jobcards").text
            job_desc.append(job_description)
        except ElementClickInterceptedException as ee:
            print(ee)
        return job_description

    def cleanData(self):
        job_description = [i.split("\n")
                           for i in self.getJobDesc().split("days ago")]
        job_cards = [i[1:-2] for i in job_description[1:]]
        job_cards.append(job_description[0])
        return job_cards

# %%
# jobs_all_pages = []
# def getDataframe(jobs_desc):
#     location = []
#     job_role = []
#     company = []
#     salary = []
#     salary_index = []
#     for i in range(len(jobs_desc)):
#         for j in range(len(jobs_desc[i])):
#             try:
#                 for s, sal in enumerate(jobs_desc[i][j]):
#                     if "000" in jobs_desc[i][j][s]:
#                         salary.append(sal)
#                         salary_index.append(s)
#                         job_role.append(jobs_desc[i][j][0])
#                         location.append(jobs_desc[i][j][2])
#                         company.append(jobs_desc[i][j][1])
#             except IndexError as ee:
#                 print(ee)

#     return pd.DataFrame({"Location": location, "Company": company, "Salary": salary, "Job Role": job_role})

# %%
jobs_all_pages = []
pages = 20
for page in range(pages):
    foo = scrapper(location="India",keyword="GIS Developer",page = page)
    jobs_all_pages.append(foo.cleanData())
getDataframe(jobs_all_pages)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_17236\3431696956.py:15: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=path, options=options)
#                     Location               Company  \
# 0             LTIMindtree3.7                   new
# 1                    Rapidor                   new
# 2       Bhubaneshwar, Orissa     Triconn Solutions
# 3        Chennai, Tamil Nadu        LTIMindtree3.7
# 4    Remote in Kochi, Kerala               Rapidor
# ..                       ...                   ...
# 102         New Delhi, Delhi       Redian Software
# 103     Hyderabad, Telangana              eXertERP
# 104        Pune, Maharashtra           Map My Crop
# 105        Pune, Maharashtra           Map My Crop
# 106     Bengaluru, Karnataka  Theron International
#
#                             Salary            Job Role
# 0    ₹5,00,000 - ₹11,00,000 a year  GIS Developer ESRI
# 1          Up to ₹18,00,000 a year      Java Developer
# 2        ₹30,000 - ₹50,000 a month       GIS Developer
# 3    ₹5,00,000 - ₹11,00,000 a year  GIS Developer ESRI
# 4          Up to ₹18,00,000 a year      Java Developer
# ..                             ...                 ...
# 102               ₹8,00,000 a year       GIS Developer
# 103          ₹7,000 - ₹7,500 a day       GIS Developer
# 104      ₹30,000 - ₹50,000 a month   Web-GIS Developer
# 105   ₹2,40,000 - ₹3,50,000 a year   Web-GIS Developer
# 106  ₹4,50,000 - ₹18,00,000 a year       GIS Developer
#
# [107 rows x 4 columns]
